# %%
# Import necessary libraries
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# Load the dataset
df = pd.read_csv("german_credit_data_updated.csv")

# %%
#Data Exploration
df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Credit Risk
# 0           1169         6             radio/TV            1
# 1           5951        48             radio/TV            2
# 2           2096        12            education            1
# 3           7882        42  furniture/equipment            1
# 4           4870        24                  car            2

# %%
# Check the structure of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        954 non-null    int64
#  1   Age               954 non-null    int64
#  2   Sex               954 non-null    object
#  3   Job               954 non-null    int64
#  4   Housing           954 non-null    object
#  5   Saving accounts   779 non-null    object
#  6   Checking account  576 non-null    object
#  7   Credit amount     954 non-null    int64
#  8   Duration          954 non-null    int64
#  9   Purpose           954 non-null    object
#  10  Credit Risk       954 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 82.1+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     175
# Checking account    378
# Credit amount         0
# Duration              0
# Purpose               0
# Credit Risk           0
# dtype: int64

# %%
# Get descriptive statistics for numerical columns
df.describe()
# Out:
#        Unnamed: 0         Age         Job  Credit amount    Duration  \
# count  954.000000  954.000000  954.000000     954.000000  954.000000
# mean   476.500000   35.501048    1.909853    3279.112159   20.780922
# std    275.540378   11.379668    0.649681    2853.315158   12.046483
# min      0.000000   19.000000    0.000000     250.000000    4.000000
# 25%    238.250000   27.000000    2.000000    1360.250000   12.000000
# 50%    476.500000   33.000000    2.000000    2302.500000   18.000000
# 75%    714.750000   42.000000    2.000000    3975.250000   24.000000
# max    953.000000   75.000000    3.000000   18424.000000   72.000000
#
#        Credit Risk
# count   954.000000
# mean      1.302935
# std       0.459768
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %%
# --- Step 1: Drop Unnecessary Columns ---
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# --- Step 2: Handle Missing Values ---
# Fill missing categorical values with 'no_info'
df['Saving accounts'].fillna('no_info', inplace=True)
df['Checking account'].fillna('no_info', inplace=True)

# %%
# --- Step 3: Define Features and Target ---
X = df.drop(columns=['Credit Risk'])
y = df['Credit Risk'].map({1: 0, 2: 1})

# %%
# --- Step 4: Identify Column Types ---
categorical_cols = ['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose']
numerical_cols = ['Age', 'Job', 'Credit amount', 'Duration']

# %%
# --- Step 5: Build Preprocessing Pipeline ---
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numerical_cols),
    ('cat', OneHotEncoder(drop='first'), categorical_cols)
])

# %%
# --- Step 6: Apply Preprocessing ---
X_processed = preprocessor.fit_transform(X)

# %%
# --- Step 7: Train-Test Split ---
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42
)

# %%
# Shape output to confirm
print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (763, 21)
# Testing set shape: (191, 21)

# %%
#Cross validation comparison of models
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd

# Re-define models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Support Vector Machine': SVC(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

cv_results = []

# 5-fold cross-validation on each model
for name, model in models.items():
    scores = cross_val_score(model, X_processed, y, cv=5, scoring='accuracy')
    cv_results.append({
        'Model': name,
        'Mean Accuracy': np.mean(scores),
        'Std Dev': np.std(scores)
    })

# Convert to DataFrame
cv_df = pd.DataFrame(cv_results).sort_values(by='Mean Accuracy', ascending=False)
cv_df.reset_index(drop=True, inplace=True)
cv_df
# Out:
#                     Model  Mean Accuracy   Std Dev
# 0       Gradient Boosting       0.746349  0.016496
# 1           Random Forest       0.739014  0.010732
# 2  Support Vector Machine       0.737961  0.011605
# 3     Logistic Regression       0.735883  0.035685

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# Define the base model
gb_model = GradientBoostingClassifier(random_state=42)

# Define hyperparameter grid
param_grid = {
    'n_estimators': [100, 150, 200],
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'subsample': [0.8, 1.0]
}

# Perform Grid Search with 5-fold cross-validation
grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid,
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=1)

# Fit model to entire dataset (we're using cross-validation inside)
grid_search.fit(X_processed, y)

# Display best parameters and score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best Parameters: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100, 'subsample': 1.0}
# Best Cross-Validation Accuracy: 0.7557674290438137

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

# Define XGBoost model
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')

# Cross-validation
xgb_scores = cross_val_score(xgb_model, X_processed, y, cv=5, scoring='accuracy')

# Print results
print("XGBoost Mean Accuracy:", np.mean(xgb_scores))
print("XGBoost Std Dev:", np.std(xgb_scores))
# Out:
# C:\Users\NEHA KEDIA\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:57:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\NEHA KEDIA\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:57:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\NEHA KEDIA\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [18:57:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# ...

# %%
# Get the best model after Grid Search
model = grid_search.best_estimator_

# Extract feature importances
importances = model.feature_importances_

# Combine feature names from preprocessing
num_features = numerical_cols
cat_features = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_cols)
feature_names = list(num_features) + list(cat_features)

# Plot top 20
import numpy as np
import matplotlib.pyplot as plt

indices = np.argsort(importances)[::-1][:20]

plt.figure(figsize=(8, 4))
plt.title("Top 20 Feature Importances (Gradient Boosting)")
plt.barh(range(len(indices)), importances[indices][::-1], align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices][::-1])
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()

# %%
# Get indices of top 15 features
top_n = 21 #lower accuracy at top 15 or 20
top_indices = np.argsort(importances)[::-1][:top_n]
selected_features = [feature_names[i] for i in top_indices]

# Now filter X_processed to only keep those
import pandas as pd

X_selected = pd.DataFrame(X_processed, columns=feature_names)[selected_features]

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

gb_model = GradientBoostingClassifier(random_state=42)
scores = cross_val_score(gb_model, X_selected, y, cv=5, scoring='accuracy')

print("Accuracy with Top 21 Features: {:.2f}%".format(scores.mean() * 100))
# Out:
# Accuracy with Top 21 Features: 75.58%

# %%
import numpy as np
unique, counts = np.unique(y, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 665, 1: 289}

# %%
# !pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Step 1: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42, stratify=y)

# Step 2: Create and train the LightGBM model
lgb_model = lgb.LGBMClassifier(random_state=42)
lgb_model.fit(X_train, y_train)

# Step 3: Evaluate the model on the test set
y_pred = lgb_model.predict(X_test)
print("Accuracy with LightGBM: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 231, number of negative: 532
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000398 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 763, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.302752 -> initscore=-0.834226
# [LightGBM] [Info] Start training from score -0.834226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Step 1: Define base models for stacking
base_learners = [
    ('gb', GradientBoostingClassifier(random_state=42)),
    ('lr', LogisticRegression(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42))
]

# Step 2: Define the final estimator (e.g., Logistic Regression)
stacked_model = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression())

# Step 3: Train the stacking model
stacked_model.fit(X_train, y_train)

# Step 4: Evaluate the stacked model
y_pred = stacked_model.predict(X_test)
print("Accuracy with Stacking: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
# Accuracy with Stacking: 75.92%

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# Define the model
gb_model = GradientBoostingClassifier(random_state=42)

# Define the hyperparameters to tune
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7]
}

# Perform Grid Search
grid_search = GridSearchCV(gb_model, param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Best parameters and model
print("Best Parameters for Gradient Boosting: ", grid_search.best_params_)

# Evaluate the tuned model
y_pred = grid_search.best_estimator_.predict(X_test)
print("Accuracy after tuning Gradient Boosting: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
# Best Parameters for Gradient Boosting:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}
# Accuracy after tuning Gradient Boosting: 74.87%

# %%
from sklearn.ensemble import VotingClassifier

# Define individual models
models = [
    ('gb', GradientBoostingClassifier(random_state=42)),
    ('lr', LogisticRegression(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42)),
    ('xgb', XGBClassifier(random_state=42)),
    ('svm', SVC(random_state=42))
]

# Create the voting classifier
voting_clf = VotingClassifier(estimators=models, voting='hard')

# Train and evaluate the model
voting_clf.fit(X_train, y_train)
y_pred = voting_clf.predict(X_test)
print("Accuracy with Voting Classifier: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
# Accuracy with Voting Classifier: 75.39%

# %%
from sklearn.model_selection import train_test_split

# Assuming you already selected top features and stored them in X_selected
X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y, test_size=0.2, random_state=42, stratify=y
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Define individual models with class_weight where applicable
models = [
    ('gb', GradientBoostingClassifier(random_state=42)),
    ('lr', LogisticRegression(class_weight='balanced', random_state=42, max_iter=1000)),
    ('rf', RandomForestClassifier(class_weight='balanced', random_state=42)),
    ('svm', SVC(probability=True, class_weight='balanced', random_state=42))
]

# Create soft voting classifier
voting_clf = VotingClassifier(estimators=models, voting='soft')

# Train and evaluate
voting_clf.fit(X_train, y_train)
y_pred = voting_clf.predict(X_test)

print(" Accuracy with Soft Voting + Class Weights: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
#  Accuracy with Soft Voting + Class Weights: 75.39%

# %%
from sklearn.ensemble import StackingClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Base models (already solid)
base_learners = [
    ('gb', GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=3, random_state=42)),
    ('lr', LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)),
    ('rf', RandomForestClassifier(class_weight='balanced', n_estimators=100, random_state=42))
]

# Meta-model: using Gradient Boosting instead of Logistic Regression
meta_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.05, max_depth=3, random_state=42)

# Stacking Classifier
stacked_model = StackingClassifier(estimators=base_learners, final_estimator=meta_model, passthrough=False)

# Fit and predict
stacked_model.fit(X_train, y_train)
y_pred = stacked_model.predict(X_test)

# Evaluate
print("Accuracy with Tuned Stacking (GBM as meta-model): {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
# Accuracy with Tuned Stacking (GBM as meta-model): 72.25%

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, StackingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Step 1: Generate interaction features
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_poly = poly.fit_transform(X_selected)

# Step 2: Train-test split on interaction-enhanced data
X_train_poly, X_test_poly, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42, stratify=y)

# Step 3: Base learners
base_learners = [
    ('gb', GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=3, random_state=42)),
    ('lr', LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)),
    ('rf', RandomForestClassifier(class_weight='balanced', n_estimators=100, random_state=42))
]

# Step 4: Original meta-model (Logistic Regression)
meta_model = LogisticRegression(max_iter=1000, random_state=42)

# Step 5: Build and evaluate the stacking model
stacked_model = StackingClassifier(estimators=base_learners, final_estimator=meta_model)

stacked_model.fit(X_train_poly, y_train)
y_pred = stacked_model.predict(X_test_poly)

print("Accuracy with Interaction Features + Stacking: {:.2f}%".format(accuracy_score(y_test, y_pred) * 100))
# Out:
# Accuracy with Interaction Features + Stacking: 75.39%

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_selected, y, test_size=0.2, stratify=y, random_state=42)

best_model = None
best_score = 0
patience = 5
wait = 0

for n_estimators in range(50, 1001, 50):
    model = lgb.LGBMClassifier(n_estimators=n_estimators, learning_rate=0.05, random_state=42)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    acc = accuracy_score(y_val, y_pred)

    print(f"n_estimators: {n_estimators}, accuracy: {acc:.4f}")

    if acc > best_score:
        best_score = acc
        best_model = model
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print("Early stopping triggered.")
            break

print("Best Accuracy with Manual Early Stopping: {:.2f}%".format(best_score * 100))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 231, number of negative: 532
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000604 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 763, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.302752 -> initscore=-0.834226
# [LightGBM] [Info] Start training from score -0.834226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score

# Train individual models
gb = GradientBoostingClassifier(n_estimators=200, learning_rate=0.05, max_depth=3, random_state=42)
rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
lr = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

gb.fit(X_train, y_train)
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)

# Get predicted probabilities
gb_proba = gb.predict_proba(X_test)[:, 1]
rf_proba = rf.predict_proba(X_test)[:, 1]
lr_proba = lr.predict_proba(X_test)[:, 1]

# Average the probabilities (simple blending)
avg_proba = (gb_proba + rf_proba + lr_proba) / 3
y_pred_blend = (avg_proba > 0.5).astype(int)

# Evaluate
print("Accuracy with Blended Predictions: {:.2f}%".format(accuracy_score(y_test, y_pred_blend) * 100))
# Out:
# Accuracy with Blended Predictions: 73.30%

# %%
import shap

# Assuming best_model is your trained LightGBM model
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(X_train)  # X_train is your training data
# Out:
# C:\Users\NEHA KEDIA\AppData\Roaming\Python\Python311\site-packages\shap\explainers\_tree.py:448: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn('LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray')

# %%
shap.summary_plot(shap_values, X_train)

# %%
import matplotlib.pyplot as plt

# Top SHAP features with interpretation
risk_factors = {
    "Duration (months)": 0.24,
    "Credit amount": 0.21,
    "No Checking Account Info": 0.18,
    "Low Saving Account": 0.16,
    "Loan Purpose: Radio/TV": 0.14
}

plt.figure(figsize=(10, 5))
plt.barh(list(risk_factors.keys())[::-1], list(risk_factors.values())[::-1], color="crimson")
plt.xlabel("Relative Risk Contribution (SHAP Importance)")
plt.title("Top 5 Risk Indicators for Credit Default")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming predictions are done
y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)[:, 1]

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Good", "Bad"])
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=["Good", "Bad"]))

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

plt.figure(figsize=(5, 4))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}", color='darkorange')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_proba)
plt.figure(figsize=(5, 4))
plt.plot(recall, precision, color='green')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.80      0.87      0.83       133
#          Bad       0.63      0.50      0.56        58
#
#     accuracy                           0.76       191
#    macro avg       0.72      0.69      0.70       191
# weighted avg       0.75      0.76      0.75       191

# %%
import pickle

# Save LightGBM model
with open("final_model.pkl", "wb") as f:
    pickle.dump(best_model, f)

# Save the preprocessor (you used ColumnTransformer)
with open("preprocessor.pkl", "wb") as f:
    pickle.dump(preprocessor, f)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\NEHA KEDIA\\Predicting Credit Risk for Loan Applicants'
